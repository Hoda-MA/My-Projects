# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')
#sns.set_palette(sns.xkcd_palette(sample_colors))
import warnings
warnings.filterwarnings("ignore")

# %%
#Die einmal gesetzten Parameter greifen für alle nachfolgenden Plots, die mit plt erzeugt wurden.
plt.rc('font', size=14)          # controls default text sizes
plt.rc('axes', titlesize=14)     # fontsize of the axes title
plt.rc('axes', labelsize=14)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)    # fontsize of the tick labels
plt.rc('ytick', labelsize=14)    # fontsize of the tick labels
plt.rc('legend', fontsize=10)    # legend fontsize
plt.rc('figure', titlesize=12)   # fontsize of the figure title
plt.rc('lines', linewidth=10, color='r')
plt.rcParams['figure.figsize']=(16,8)
Set1=['Red', 'Yellow', 'Navy', 'pink','purple','black','Blue']

# %%
test=pd.read_csv('test.csv')
test.head(2)
#test.info()
# Out:
#      id                              belongs_to_collection  budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...       0
# 1  3002                                                NaN   88000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
#
#   original_language               original_title  \
# 0                ja           ディアルガVSパルキアVSダークライ
# 1                en  Attack of the 50 Foot Woman
#
#                                             overview  popularity  ...  \
# 0  Ash and friends (this time accompanied by newc...    3.851534  ...
# 1  When an abused wife grows to giant size becaus...    3.559789  ...
#
# ...

# %%
train=pd.read_csv('train.csv')
train.head(2)
#train.info()
#train.describe()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# ...

# %%
test.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
# ordering the columns as desired
test=test[['id', 'imdb_id', 'title', 'popularity', 'runtime',
             'release_date', 'overview','original_language','spoken_languages','genres',
        'production_companies', 'production_countries', 'status','poster_path', 
     'tagline', 'cast', 'crew','belongs_to_collection', 'budget', 'homepage','Keywords','original_title' ]]

# %%
test.head(3)
# Out:
#      id    imdb_id                         title  popularity  runtime  \
# 0  3001  tt1226251  Pokémon: The Rise of Darkrai    3.851534     90.0
# 1  3002  tt0051380   Attack of the 50 Foot Woman    3.559789     65.0
# 2  3003  tt0118556              Addicted to Love    8.085194    100.0
#
#   release_date                                           overview  \
# 0      7/14/07  Ash and friends (this time accompanied by newc...
# 1      5/19/58  When an abused wife grows to giant size becaus...
# 2      5/23/97  Good-natured astronomer Sam is devastated when...
#
#   original_language                                   spoken_languages  \
# 0                ja  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1                en           [{'iso_639_1': 'en', 'name': 'English'}]
# 2                en           [{'iso_639_1': 'en', 'name': 'English'}]
#
#                                               genres  ...    status  \
# ...

# %%
test.sort_values('popularity',ascending=False).head(10)
# Out:
#         id    imdb_id                                             title  \
# 3380  6381  tt2293640                                           Minions
# 2977  5978  tt2245084                                        Big Hero 6
# 3151  6152  tt0499549                                            Avatar
# 1898  4899  tt2911666                                         John Wick
# 787   3788  tt1951265             The Hunger Games: Mockingjay - Part 1
# 1589  4590  tt3498820                        Captain America: Civil War
# 402   3403  tt0110912                                      Pulp Fiction
# 2680  5681  tt1790809  Pirates of the Caribbean: Dead Men Tell No Tales
# 2176  5177  tt0083658                                      Blade Runner
# 3800  6801  tt2091256          Captain Underpants: The First Epic Movie
#
#       popularity  runtime release_date  \
# 3380  547.488298     91.0      6/17/15
# 2977  213.849907    102.0     10/24/14
# 3151  185.070892    162.0     12/10/09
# ...

# %%
test.loc[test['title'] == 'Blade Runner', 'id']
# Out:
# 2176    5177
# Name: id, dtype: int64

# %%
test.loc[test['title'] == 'Blade Runner', 'id'].item()
# Out:
# 5177

# %%
test.title[0:10]
# Out:
# 0    Pokémon: The Rise of Darkrai
# 1     Attack of the 50 Foot Woman
# 2                Addicted to Love
# 3                       Incendies
# 4              Inside Deep Throat
# 5                        SubUrbia
# 6                           Three
# 7                The Tigger Movie
# 8                   Becoming Jane
# 9                     Toy Story 2
# Name: title, dtype: object

# %%
type(test.title)
# Out:
# pandas.core.series.Series

# %%
print (test.sort_values('popularity',ascending=False)['title'].astype(str).str.contains('Minions'))
# Out:
# 3380     True
# 2977    False
# 3151    False
# 1898    False
# 787     False
#         ...
# 1221    False
# 4340    False
# 3449    False
# 243     False
# 830     False
# Name: title, Length: 4398, dtype: bool
